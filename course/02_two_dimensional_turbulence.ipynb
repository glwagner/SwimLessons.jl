# %% [markdown]
# # Two-dimensional turbulence, operations, and diagnostics
#
# Let's step it up a notch over the last tutorial and consider a _two_-dimensional problem.
# To keep the physics simple, we'll just consider freely-decaying two-dimensional turbulence from a random initial state.
# So now we will be solving
#
# $$ \partial_t u + \partial_x \left ( u^2 \right ) + \partial_y \left ( uv \right ) + \partial_x p = 0 $$
# $$ \partial_t v + \partial_x \left ( u v \right ) + \partial_y \left ( v^2 \right ) + \partial_y p = 0 $$
# $$ \partial_x u + \partial_y v = 0 $$
#
# Note that we've included no explicit diffusion.
# That's because we're going to use
#
# This can be simulated an alarmingly small number of lines with Oceananigans,

# %%
using Oceananigans
using GLMakie

Nx = Ny = 128
grid = RectilinearGrid(size=(Nx, Ny), x=(0, 1), y=(0, 1), topology=(Periodic, Periodic, Flat))
model = NonhydrostaticModel(; grid, advection=WENO(order=5))
ui(x, y) = randn()
set!(model, u=ui, v=ui)
simulation = Simulation(model, Δt=0.1/Nx, stop_iteration=200)
run!(simulation)
heatmap(interior(model.velocities.u, :, :, 1), axis=(; aspect=1))
# Out:
# [ Info: Initializing simulation...
# [ Info:     ... simulation initialization complete (7.375 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (15.594 ms).
# [ Info: Simulation is stopping after running for 1.536 seconds.
# [ Info: Model iteration 200 equals or exceeds stop iteration 200.

# %% [markdown]
# # Operations and diagnostics
#
# Turbulence is great, but it's pointless to simulate it unless we can somehow analyze the results.
# To facilitate analysis, Oceananigans has a system for building up expression trees of "operations" --- basically, derivatives, arithmetic, and functions like `sqrt(x)` on a staggered grid --- in terms of Oceananigans fields.
# To see what that looks like, let's start by computing the speed in the above model,

# %%
u, v, w = model.velocities
s_op = sqrt(u^2 + v^2)
# Out:
# UnaryOperation at (Face, Center, Center)
# ├── grid: 128×128×1 RectilinearGrid{Float64, Periodic, Periodic, Flat} on CPU with 3×3×0 halo
# └── tree:
#     sqrt at (Face, Center, Center) via identity
#     └── + at (Face, Center, Center)
#         ├── ^ at (Face, Center, Center)
#         │   ├── 128×128×1 Field{Face, Center, Center} on RectilinearGrid on CPU
#         │   └── 2
#         └── ^ at (Center, Face, Center)
#             ├── 128×128×1 Field{Center, Face, Center} on RectilinearGrid on CPU
#             └── 2

# %% [markdown]
# The object `s_op` is a `UnaryOperation` --- that is, an operation with one argument.
# In this case the operation is `sqrt`, and the argument is itself an operation:

# %%
s_op.arg
# Out:
# BinaryOperation at (Face, Center, Center)
# ├── grid: 128×128×1 RectilinearGrid{Float64, Periodic, Periodic, Flat} on CPU with 3×3×0 halo
# └── tree:
#     + at (Face, Center, Center)
#     ├── ^ at (Face, Center, Center)
#     │   ├── 128×128×1 Field{Face, Center, Center} on RectilinearGrid on CPU
#     │   └── 2
#     └── ^ at (Center, Face, Center)
#         ├── 128×128×1 Field{Center, Face, Center} on RectilinearGrid on CPU
#         └── 2

# %% [markdown]
# namely, of `+`. And so on --- `s_op` is an expression tree that first computes `u^2` and `v^2`, then adds them together, then computes the square root.
#
# An "operation" is a bit like a `Field`, in that we can index into it like so

# %%
s_op[1, 1, 1]
# Out:
# 0.032883169196124225

# %% [markdown]
# But it's also not like a `Field` because it has no underlying data.
# In other words, `s_op` is a _lazy_ representation of the expression tree.
#
# Before showing how to actually compute the speed over the whole grid, let's pause for a moment and note that `s_op` has a "location",

# %%
location(s_op)
# Out:
# (Face, Center, Center)

# %% [markdown]
# which is actually the same location as `u`,

# %%
location(u)
# Out:
# (Face, Center, Center)

# %% [markdown]
# That's because we built `s_op` without specifying a staggered-grid location, so it took by default the location of the first `Field` argument in the expression tree.
# Sometimes living with that default is fine, but other times it's not.
# In this case, let's make sure that `s_op` is computed at cell _centers_,s_op = @at (Center, Center, Center) sqrt(u^2 + v^2)

# %%
s_op = @at (Center, Center, Center) sqrt(u^2 + v^2)
# Out:
# UnaryOperation at (Center, Center, Center)
# ├── grid: 128×128×1 RectilinearGrid{Float64, Periodic, Periodic, Flat} on CPU with 3×3×0 halo
# └── tree:
#     sqrt at (Center, Center, Center) via identity
#     └── + at (Center, Center, Center)
#         ├── ^ at (Face, Center, Center)
#         │   ├── 128×128×1 Field{Face, Center, Center} on RectilinearGrid on CPU
#         │   └── 2
#         └── ^ at (Center, Face, Center)
#             ├── 128×128×1 Field{Center, Face, Center} on RectilinearGrid on CPU
#             └── 2

# %% [markdown]
# That's better.
# Note that `u^2` and `v^2` are both computed at their respective locations, for example,

# %%
s_op.arg.a
# Out:
# BinaryOperation at (Face, Center, Center)
# ├── grid: 128×128×1 RectilinearGrid{Float64, Periodic, Periodic, Flat} on CPU with 3×3×0 halo
# └── tree:
#     ^ at (Face, Center, Center)
#     ├── 128×128×1 Field{Face, Center, Center} on RectilinearGrid on CPU
#     └── 2

# %% [markdown]
# and it's only when forming the sum of `u^2` and `v^2` that we average these expressions to cell centers.
# Generally that's what we want, to delay the averaging as long as possible.
#
# Now we are ready to allocate some memory for _speed_, and then compute it.
# To do this we wrap `s_op` in `Field`,

# %%
s = Field(s_op)
# Out:
# 128×128×1 Field{Center, Center, Center} on RectilinearGrid on CPU
# ├── grid: 128×128×1 RectilinearGrid{Float64, Periodic, Periodic, Flat} on CPU with 3×3×0 halo
# ├── boundary conditions: FieldBoundaryConditions
# │   └── west: Periodic, east: Periodic, south: Periodic, north: Periodic, bottom: Nothing, top: Nothing, immersed: ZeroFlux
# ├── operand: UnaryOperation at (Center, Center, Center)
# ├── status: time=0.0
# └── data: 134×134×1 OffsetArray(::Array{Float64, 3}, -2:131, -2:131, 1:1) with eltype Float64 with indices -2:131×-2:131×1:1
#     └── max=0.0, min=0.0, mean=0.0

# %% [markdown]
# Now we have a proper `Field` `s` that has data.
# But note that the data is all zero. That's because we don't `compute!` anything unless we really want to --- sometimes `compute!` is expensive.
# To actually perform the computation we write

# %%
compute!(s)
# Out:
# 128×128×1 Field{Center, Center, Center} on RectilinearGrid on CPU
# ├── grid: 128×128×1 RectilinearGrid{Float64, Periodic, Periodic, Flat} on CPU with 3×3×0 halo
# ├── boundary conditions: FieldBoundaryConditions
# │   └── west: Periodic, east: Periodic, south: Periodic, north: Periodic, bottom: Nothing, top: Nothing, immersed: ZeroFlux
# ├── operand: UnaryOperation at (Center, Center, Center)
# ├── status: time=0.0
# └── data: 134×134×1 OffsetArray(::Array{Float64, 3}, -2:131, -2:131, 1:1) with eltype Float64 with indices -2:131×-2:131×1:1
#     └── max=0.535869, min=0.004022, mean=0.181466

# %% [markdown]
# Now we've got something.
# Note we could have also used the shorthand `s = compute!(Field(s_op))` to build a `Field` and `compute!` it in a single line.
#
# Next we'll make a vorticity field,

# %%
ω_op = ∂x(v) - ∂y(u)
ω = compute!(Field(ω_op))
# Out:
# 128×128×1 Field{Face, Face, Center} on RectilinearGrid on CPU
# ├── grid: 128×128×1 RectilinearGrid{Float64, Periodic, Periodic, Flat} on CPU with 3×3×0 halo
# ├── boundary conditions: FieldBoundaryConditions
# │   └── west: Periodic, east: Periodic, south: Periodic, north: Periodic, bottom: Nothing, top: Nothing, immersed: ZeroFlux
# ├── operand: BinaryOperation at (Face, Face, Center)
# ├── status: time=0.0
# └── data: 134×134×1 OffsetArray(::Array{Float64, 3}, -2:131, -2:131, 1:1) with eltype Float64 with indices -2:131×-2:131×1:1
#     └── max=46.5898, min=-43.7634, mean=-1.61329e-16

# %% [markdown]
# And finally, plot the results:

# %%
fig = Figure(size=(1200, 700))
axω = Axis(fig[1, 1], xlabel="x", ylabel="y", aspect=1)
axs = Axis(fig[1, 2], xlabel="x", ylabel="y", aspect=1)

ωlim = 3/4 * maximum(abs, ω)
xω, yω, zω = nodes(ω)
hm = heatmap!(axω, xω, yω, interior(ω, :, :, 1), colormap=:balance, colorrange=(-ωlim, ωlim))
Colorbar(fig[0, 1], hm, label="Vorticity", vertical=false)

xs, ys, zs = nodes(s)
hm = heatmap!(axs, xs, ys, interior(s, :, :, 1), colormap=:viridis) 
Colorbar(fig[0, 2], hm, label="Speed", vertical=false)

fig

# %% [markdown]
# This system of diagnostics forms the key to interesting output during time-stepping with Oceananigans.
# We'll get to building output writers in tutorial #4.

# %% [markdown]
# # Adaptive time stepping

# %%
using Printf

set!(model, u=ui, v=ui)
model.clock.time = 0
model.clock.iteration = 0

simulation = Simulation(model, Δt=0.1/Nx, stop_iteration=1000)

conjure_time_step_wizard!(simulation, cfl=0.7)

function progress(sim)
    msg = @sprintf("Iter: %d, time: %.2e, Δt: %.2e",
                   iteration(sim), time(sim), sim.Δt)
    @info msg
    return nothing
end

simulation.callbacks[:progress] = Callback(progress, IterationInterval(10))

run!(simulation)
# Out:
# [ Info: Initializing simulation...
# [ Info: Iter: 0, time: 0.00e+00, Δt: 8.59e-04
# [ Info:     ... simulation initialization complete (20.327 ms)
# [ Info: Executing initial time step...
# [ Info:     ... initial time step complete (19.958 ms).
# [ Info: Iter: 10, time: 8.59e-03, Δt: 9.45e-04
# [ Info: Iter: 20, time: 1.80e-02, Δt: 1.04e-03
# [ Info: Iter: 30, time: 2.84e-02, Δt: 1.14e-03
# [ Info: Iter: 40, time: 3.99e-02, Δt: 1.26e-03
# [ Info: Iter: 50, time: 5.25e-02, Δt: 1.38e-03
# [ Info: Iter: 60, time: 6.63e-02, Δt: 1.52e-03
# [ Info: Iter: 70, time: 8.15e-02, Δt: 1.67e-03
# [ Info: Iter: 80, time: 9.83e-02, Δt: 1.84e-03
# [ Info: Iter: 90, time: 1.17e-01, Δt: 2.03e-03
# [ Info: Iter: 100, time: 1.37e-01, Δt: 2.23e-03
# [ Info: Iter: 110, time: 1.59e-01, Δt: 2.45e-03
# [ Info: Iter: 120, time: 1.84e-01, Δt: 2.70e-03
# [ Info: Iter: 130, time: 2.11e-01, Δt: 2.97e-03
# [ Info: Iter: 140, time: 2.40e-01, Δt: 3.26e-03
# [ Info: Iter: 150, time: 2.73e-01, Δt: 3.59e-03
# [ Info: Iter: 160, time: 3.09e-01, Δt: 3.95e-03
# [ Info: Iter: 170, time: 3.48e-01, Δt: 4.34e-03
# [ Info: Iter: 180, time: 3.92e-01, Δt: 4.78e-03
# [ Info: Iter: 190, time: 4.40e-01, Δt: 5.26e-03
# [ Info: Iter: 200, time: 4.92e-01, Δt: 5.35e-03
# [ Info: Iter: 210, time: 5.46e-01, Δt: 5.71e-03
# [ Info: Iter: 220, time: 6.03e-01, Δt: 5.96e-03
# [ Info: Iter: 230, time: 6.62e-01, Δt: 6.33e-03
# [ Info: Iter: 240, time: 7.26e-01, Δt: 6.16e-03
# [ Info: Iter: 250, time: 7.87e-01, Δt: 6.26e-03
# [ Info: Iter: 260, time: 8.50e-01, Δt: 6.09e-03
# [ Info: Iter: 270, time: 9.11e-01, Δt: 5.83e-03
# [ Info: Iter: 280, time: 9.69e-01, Δt: 5.95e-03
# [ Info: Iter: 290, time: 1.03e+00, Δt: 6.26e-03
# [ Info: Iter: 300, time: 1.09e+00, Δt: 6.68e-03
# [ Info: Iter: 310, time: 1.16e+00, Δt: 6.69e-03
# [ Info: Iter: 320, time: 1.22e+00, Δt: 6.88e-03
# [ Info: Iter: 330, time: 1.29e+00, Δt: 6.50e-03
# [ Info: Iter: 340, time: 1.36e+00, Δt: 6.19e-03
# [ Info: Iter: 350, time: 1.42e+00, Δt: 6.27e-03
# [ Info: Iter: 360, time: 1.48e+00, Δt: 6.82e-03
# [ Info: Iter: 370, time: 1.55e+00, Δt: 7.39e-03
# [ Info: Iter: 380, time: 1.63e+00, Δt: 7.47e-03
# [ Info: Iter: 390, time: 1.70e+00, Δt: 7.57e-03
# [ Info: Iter: 400, time: 1.78e+00, Δt: 6.90e-03
# [ Info: Iter: 410, time: 1.84e+00, Δt: 5.98e-03
# [ Info: Iter: 420, time: 1.90e+00, Δt: 5.73e-03
# [ Info: Iter: 430, time: 1.96e+00, Δt: 5.74e-03
# [ Info: Iter: 440, time: 2.02e+00, Δt: 6.13e-03
# [ Info: Iter: 450, time: 2.08e+00, Δt: 6.74e-03
# [ Info: Iter: 460, time: 2.15e+00, Δt: 6.62e-03
# [ Info: Iter: 470, time: 2.21e+00, Δt: 6.53e-03
# [ Info: Iter: 480, time: 2.28e+00, Δt: 6.81e-03
# [ Info: Iter: 490, time: 2.35e+00, Δt: 7.48e-03
# [ Info: Iter: 500, time: 2.42e+00, Δt: 7.89e-03
# [ Info: Iter: 510, time: 2.50e+00, Δt: 7.62e-03
# [ Info: Iter: 520, time: 2.58e+00, Δt: 7.71e-03
# [ Info: Iter: 530, time: 2.65e+00, Δt: 7.86e-03
# [ Info: Iter: 540, time: 2.73e+00, Δt: 8.14e-03
# [ Info: Iter: 550, time: 2.81e+00, Δt: 8.23e-03
# [ Info: Iter: 560, time: 2.90e+00, Δt: 7.17e-03
# [ Info: Iter: 570, time: 2.97e+00, Δt: 6.98e-03
# [ Info: Iter: 580, time: 3.04e+00, Δt: 7.09e-03
# [ Info: Iter: 590, time: 3.11e+00, Δt: 7.24e-03
# [ Info: Iter: 600, time: 3.18e+00, Δt: 7.81e-03
# [ Info: Iter: 610, time: 3.26e+00, Δt: 8.20e-03
# [ Info: Iter: 620, time: 3.34e+00, Δt: 8.75e-03
# [ Info: Iter: 630, time: 3.43e+00, Δt: 8.60e-03
# [ Info: Iter: 640, time: 3.52e+00, Δt: 8.52e-03
# [ Info: Iter: 650, time: 3.60e+00, Δt: 8.29e-03
# [ Info: Iter: 660, time: 3.68e+00, Δt: 8.19e-03
# [ Info: Iter: 670, time: 3.77e+00, Δt: 7.75e-03
# [ Info: Iter: 680, time: 3.84e+00, Δt: 7.42e-03
# [ Info: Iter: 690, time: 3.92e+00, Δt: 7.42e-03
# [ Info: Iter: 700, time: 3.99e+00, Δt: 7.33e-03
# [ Info: Iter: 710, time: 4.06e+00, Δt: 7.16e-03
# [ Info: Iter: 720, time: 4.14e+00, Δt: 7.04e-03
# [ Info: Iter: 730, time: 4.21e+00, Δt: 7.22e-03
# [ Info: Iter: 740, time: 4.28e+00, Δt: 7.14e-03
# [ Info: Iter: 750, time: 4.35e+00, Δt: 7.32e-03
# [ Info: Iter: 760, time: 4.42e+00, Δt: 7.47e-03
# [ Info: Iter: 770, time: 4.50e+00, Δt: 7.94e-03
# [ Info: Iter: 780, time: 4.58e+00, Δt: 7.93e-03
# [ Info: Iter: 790, time: 4.66e+00, Δt: 8.16e-03
# [ Info: Iter: 800, time: 4.74e+00, Δt: 7.96e-03
# [ Info: Iter: 810, time: 4.82e+00, Δt: 7.65e-03
# [ Info: Iter: 820, time: 4.89e+00, Δt: 7.31e-03
# [ Info: Iter: 830, time: 4.97e+00, Δt: 7.08e-03
# [ Info: Iter: 840, time: 5.04e+00, Δt: 6.94e-03
# [ Info: Iter: 850, time: 5.11e+00, Δt: 6.83e-03
# [ Info: Iter: 860, time: 5.18e+00, Δt: 6.53e-03
# [ Info: Iter: 870, time: 5.24e+00, Δt: 6.61e-03
# [ Info: Iter: 880, time: 5.31e+00, Δt: 6.23e-03
# [ Info: Iter: 890, time: 5.37e+00, Δt: 6.41e-03
# [ Info: Iter: 900, time: 5.43e+00, Δt: 6.58e-03
# [ Info: Iter: 910, time: 5.50e+00, Δt: 6.68e-03
# [ Info: Iter: 920, time: 5.57e+00, Δt: 7.19e-03
# [ Info: Iter: 930, time: 5.64e+00, Δt: 7.13e-03
# [ Info: Iter: 940, time: 5.71e+00, Δt: 7.38e-03
# [ Info: Iter: 950, time: 5.78e+00, Δt: 7.79e-03
# [ Info: Iter: 960, time: 5.86e+00, Δt: 7.86e-03
# [ Info: Iter: 970, time: 5.94e+00, Δt: 7.36e-03
# [ Info: Iter: 980, time: 6.01e+00, Δt: 7.13e-03
# [ Info: Iter: 990, time: 6.08e+00, Δt: 7.35e-03
# [ Info: Simulation is stopping after running for 7.888 seconds.
# [ Info: Model iteration 1000 equals or exceeds stop iteration 1000.
# [ Info: Iter: 1000, time: 6.16e+00, Δt: 7.62e-03

# %%
compute!(ω)

fig = Figure()
ax = Axis(fig[1, 1], aspect=1)
heatmap!(ax, interior(ω, :, :, 1), colormap=:balance)
fig
